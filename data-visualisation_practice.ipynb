# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("API_SP.DYN.CBRT.IN_DS2_en_csv_v2_712972.csv", skiprows = 3, index_col=False, header=0)
del df["Unnamed: 64"]
del df["Country Code"]
del df["Indicator Code"]

# %%
#df.head(5)

# %%
df.shape
# Out:
# (264, 62)

# %%
#df.isnull

# %%
df.describe()
# Out:
#              1960        1961        1962        1963        1964        1965  \
# count  239.000000  238.000000  239.000000  238.000000  238.000000  238.000000
# mean    38.117837   37.795361   37.879824   37.793809   37.336228   36.840701
# std     11.427040   11.545483   11.366611   11.383132   11.400201   11.574290
# min     13.400000   13.700000   12.900000   13.100000   13.100000   13.100000
# 25%     27.424482   26.109772   28.408000   28.326750   27.562250   26.673000
# 50%     42.702000   42.578094   42.177861   42.161823   41.827500   41.216095
# 75%     47.291000   47.212859   46.970500   46.755067   46.484884   46.134576
# max     58.122000   58.194000   58.227000   58.214000   58.152000   58.037000
#
#              1966        1967        1968        1969  ...        2010  \
# count  239.000000  238.000000  238.000000  238.000000  ...  253.000000
# mean    36.241234   35.953575   35.615478   35.215751  ...   21.994107
# ...

# %%
# %%capture
! pip install seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
print(df.dtypes)
# Out:
# Country Name       object
# Indicator Name     object
# 1960              float64
# 1961              float64
# 1962              float64
#                    ...
# 2015              float64
# 2016              float64
# 2017              float64
# 2018              float64
# 2019              float64
# Length: 62, dtype: object

# %%
df["Country Name"].unique()
# Out:
# array(['Aruba', 'Afghanistan', 'Angola', 'Albania', 'Andorra',
#        'Arab World', 'United Arab Emirates', 'Argentina', 'Armenia',
#        'American Samoa', 'Antigua and Barbuda', 'Australia', 'Austria',
#        'Azerbaijan', 'Burundi', 'Belgium', 'Benin', 'Burkina Faso',
#        'Bangladesh', 'Bulgaria', 'Bahrain', 'Bahamas, The',
#        'Bosnia and Herzegovina', 'Belarus', 'Belize', 'Bermuda',
#        'Bolivia', 'Brazil', 'Barbados', 'Brunei Darussalam', 'Bhutan',
#        'Botswana', 'Central African Republic', 'Canada',
#        'Central Europe and the Baltics', 'Switzerland', 'Channel Islands',
#        'Chile', 'China', "Cote d'Ivoire", 'Cameroon', 'Congo, Dem. Rep.',
#        'Congo, Rep.', 'Colombia', 'Comoros', 'Cabo Verde', 'Costa Rica',
#        'Caribbean small states', 'Cuba', 'Curacao', 'Cayman Islands',
#        'Cyprus', 'Czech Republic', 'Germany', 'Djibouti', 'Dominica',
#        'Denmark', 'Dominican Republic', 'Algeria',
# ...

# %%
df_group_one=df[["Country Name","1960"]]
df_group_one=df_group_one.groupby(["Country Name"], as_index=False).mean()
df_group_one
# Out:
#            Country Name       1960
# 0           Afghanistan  51.279000
# 1               Albania  40.924000
# 2               Algeria  49.656000
# 3        American Samoa        NaN
# 4               Andorra        NaN
# ..                  ...        ...
# 259  West Bank and Gaza        NaN
# 260               World  31.752462
# 261         Yemen, Rep.  53.504000
# 262              Zambia  49.672000
# 263            Zimbabwe  47.996000
#
# [264 rows x 2 columns]

# %%
missing_data=df.isnull()
missing_data.head(10)
# Out:
#    Country Name  Indicator Name   1960   1961   1962   1963   1964   1965  \
# 0         False           False  False  False  False  False  False  False
# 1         False           False  False  False  False  False  False  False
# 2         False           False  False  False  False  False  False  False
# 3         False           False  False  False  False  False  False  False
# 4         False           False   True   True   True   True   True   True
# 5         False           False  False  False  False  False  False  False
# 6         False           False  False  False  False  False  False  False
# 7         False           False  False  False  False  False  False  False
# 8         False           False  False  False  False  False  False  False
# 9         False           False   True   True   True   True   True   True
#
#     1966   1967  ...   2010   2011   2012   2013   2014   2015   2016   2017  \
# ...

# %%
for column in missing_data.columns.values.tolist():
    print(missing_data[column].value_counts())
    print("")
    print(column)
# Out:
# False    264
# Name: Country Name, dtype: int64
#
# Country Name
# False    264
# Name: Indicator Name, dtype: int64
#
# Indicator Name
# False    239
# True      25
# Name: 1960, dtype: int64
#
# 1960
# False    238
# True      26
# Name: 1961, dtype: int64
#
# 1961
# False    239
# True      25
# Name: 1962, dtype: int64
#
# 1962
# False    238
# True      26
# Name: 1963, dtype: int64
#
# 1963
# False    238
# True      26
# Name: 1964, dtype: int64
#
# 1964
# False    238
# True      26
# Name: 1965, dtype: int64
#
# 1965
# False    239
# True      25
# Name: 1966, dtype: int64
#
# 1966
# False    238
# True      26
# Name: 1967, dtype: int64
#
# 1967
# False    238
# True      26
# Name: 1968, dtype: int64
#
# 1968
# False    238
# True      26
# Name: 1969, dtype: int64
#
# 1969
# False    242
# True      22
# Name: 1970, dtype: int64
#
# 1970
# False    240
# True      24
# Name: 1971, dtype: int64
#
# 1971
# False    241
# True      23
# Name: 1972, dtype: int64
#
# 1972
# ...

# %%
df.head()
# Out:
#   Country Name                        Indicator Name    1960    1961    1962  \
# 0        Aruba  Birth rate, crude (per 1,000 people)  35.679  34.529  33.320
# 1  Afghanistan  Birth rate, crude (per 1,000 people)  51.279  51.373  51.457
# 2       Angola  Birth rate, crude (per 1,000 people)  49.080  48.779  48.547
# 3      Albania  Birth rate, crude (per 1,000 people)  40.924  40.368  39.627
# 4      Andorra  Birth rate, crude (per 1,000 people)     NaN     NaN     NaN
#
#      1963    1964    1965    1966    1967  ...    2010    2011    2012  \
# 0  32.050  30.737  29.413  28.121  26.908  ...  11.214  11.123  11.090
# 1  51.530  51.589  51.631  51.652  51.650  ...  39.829  38.750  37.690
# 2  48.430  48.450  48.622  48.936  49.343  ...  45.656  45.102  44.493
# 3  38.723  37.695  36.599  35.496  34.435  ...  12.001  12.100  12.197
# 4     NaN     NaN     NaN     NaN     NaN  ...   9.800     NaN   9.500
#
#      2013    2014    2015    2016    2017  2018  2019
# ...

# %%
country_birth_rates = df
del country_birth_rates["2018"]
del country_birth_rates["2019"]
#country_birth_rates = country_birth_rates[~np.all(country_birth_rates == 0, axis=1)]
country_birth_rates.dropna(how = "any").head()
# Out:
#   Country Name                        Indicator Name       1960       1961  \
# 0        Aruba  Birth rate, crude (per 1,000 people)  35.679000  34.529000
# 1  Afghanistan  Birth rate, crude (per 1,000 people)  51.279000  51.373000
# 2       Angola  Birth rate, crude (per 1,000 people)  49.080000  48.779000
# 3      Albania  Birth rate, crude (per 1,000 people)  40.924000  40.368000
# 5   Arab World  Birth rate, crude (per 1,000 people)  47.790076  47.558391
#
#         1962       1963       1964       1965       1966      1967  ...  \
# 0  33.320000  32.050000  30.737000  29.413000  28.121000  26.90800  ...
# 1  51.457000  51.530000  51.589000  51.631000  51.652000  51.65000  ...
# 2  48.547000  48.430000  48.450000  48.622000  48.936000  49.34300  ...
# 3  39.627000  38.723000  37.695000  36.599000  35.496000  34.43500  ...
# 5  47.327603  47.091616  46.844209  46.577098  46.282911  45.96055  ...
#
#         2008    2009       2010       2011       2012       2013       2014  \
# ...

# %%
del country_birth_rates["Indicator Name"]

# %%
country_birth_rates.head()
# Out:
#   Country Name    1960    1961    1962    1963    1964    1965    1966  \
# 0        Aruba  35.679  34.529  33.320  32.050  30.737  29.413  28.121
# 1  Afghanistan  51.279  51.373  51.457  51.530  51.589  51.631  51.652
# 2       Angola  49.080  48.779  48.547  48.430  48.450  48.622  48.936
# 3      Albania  40.924  40.368  39.627  38.723  37.695  36.599  35.496
# 4      Andorra     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#      1967    1968  ...    2008    2009    2010    2011    2012    2013  \
# 0  26.908  25.817  ...  11.556  11.361  11.214  11.123  11.090  11.111
# 1  51.650  51.623  ...  41.949  40.903  39.829  38.750  37.690  36.670
# 2  49.343  49.787  ...  46.563  46.143  45.656  45.102  44.493  43.847
# 3  34.435  33.458  ...  11.973  11.945  12.001  12.100  12.197  12.257
# 4     NaN     NaN  ...  10.400   9.900   9.800     NaN   9.500     NaN
#
#      2014    2015    2016    2017
# 0  11.179  11.281  11.404  11.532
# 1  35.706  34.809  33.981  33.211
# ...

# %%
country_birth_rates = country_birth_rates.dropna(how = "any")

# %%
country_birth_rates.set_index(country_birth_rates["Country Name"], inplace = True)
#country_birth_rates.head()

# %%
years = list(map(str, range(1960,2017)))
country_birth_rates_transposed = country_birth_rates[years].transpose()

# %%
del country_birth_rates["Country Name"]

# %%
country_birth_rates.head()
# Out:
#                    1960       1961       1962       1963       1964  \
# Country Name
# Aruba         35.679000  34.529000  33.320000  32.050000  30.737000
# Afghanistan   51.279000  51.373000  51.457000  51.530000  51.589000
# Angola        49.080000  48.779000  48.547000  48.430000  48.450000
# Albania       40.924000  40.368000  39.627000  38.723000  37.695000
# Arab World    47.790076  47.558391  47.327603  47.091616  46.844209
#
#                    1965       1966      1967       1968       1969  ...  \
# Country Name                                                        ...
# Aruba         29.413000  28.121000  26.90800  25.817000  24.872000  ...
# Afghanistan   51.631000  51.652000  51.65000  51.623000  51.574000  ...
# Angola        48.622000  48.936000  49.34300  49.787000  50.231000  ...
# Albania       36.599000  35.496000  34.43500  33.458000  32.590000  ...
# Arab World    46.577098  46.282911  45.96055  45.611372  45.237163  ...
#
# ...

# %%
country_birth_rates.head(20)
# Out:
#             Country Name                        Indicator Name       1960  \
# 0                  Aruba  Birth rate, crude (per 1,000 people)  35.679000
# 1            Afghanistan  Birth rate, crude (per 1,000 people)  51.279000
# 2                 Angola  Birth rate, crude (per 1,000 people)  49.080000
# 3                Albania  Birth rate, crude (per 1,000 people)  40.924000
# 5             Arab World  Birth rate, crude (per 1,000 people)  47.790076
# 6   United Arab Emirates  Birth rate, crude (per 1,000 people)  47.266000
# 7              Argentina  Birth rate, crude (per 1,000 people)  23.775000
# 8                Armenia  Birth rate, crude (per 1,000 people)  38.509000
# 10   Antigua and Barbuda  Birth rate, crude (per 1,000 people)  32.829000
# 11             Australia  Birth rate, crude (per 1,000 people)  22.400000
# 12               Austria  Birth rate, crude (per 1,000 people)  17.900000
# 13            Azerbaijan  Birth rate, crude (per 1,000 people)  45.931000
# ...

# %%
import matplotlib.pyplot as plt

# %%
df2 = df.set_index(df["Country Name"])
del df2["Country Name"]
# Out:
#   Country Name                        Indicator Name    1960    1961    1962  \
# 0        Aruba  Birth rate, crude (per 1,000 people)  35.679  34.529  33.320
# 1  Afghanistan  Birth rate, crude (per 1,000 people)  51.279  51.373  51.457
# 2       Angola  Birth rate, crude (per 1,000 people)  49.080  48.779  48.547
# 3      Albania  Birth rate, crude (per 1,000 people)  40.924  40.368  39.627
# 4      Andorra  Birth rate, crude (per 1,000 people)     NaN     NaN     NaN
#
#      1963    1964    1965    1966    1967  ...    2010    2011    2012  \
# 0  32.050  30.737  29.413  28.121  26.908  ...  11.214  11.123  11.090
# 1  51.530  51.589  51.631  51.652  51.650  ...  39.829  38.750  37.690
# 2  48.430  48.450  48.622  48.936  49.343  ...  45.656  45.102  44.493
# 3  38.723  37.695  36.599  35.496  34.435  ...  12.001  12.100  12.197
# 4     NaN     NaN     NaN     NaN     NaN  ...   9.800     NaN   9.500
#
#      2013    2014    2015    2016    2017  2018  2019
# ...

# %%
df2.head()
# Out:
#                                     Indicator Name    1960    1961    1962  \
# Country Name
# Aruba         Birth rate, crude (per 1,000 people)  35.679  34.529  33.320
# Afghanistan   Birth rate, crude (per 1,000 people)  51.279  51.373  51.457
# Angola        Birth rate, crude (per 1,000 people)  49.080  48.779  48.547
# Albania       Birth rate, crude (per 1,000 people)  40.924  40.368  39.627
# Andorra       Birth rate, crude (per 1,000 people)     NaN     NaN     NaN
#
#                 1963    1964    1965    1966    1967    1968  ...    2010  \
# Country Name                                                  ...
# Aruba         32.050  30.737  29.413  28.121  26.908  25.817  ...  11.214
# Afghanistan   51.530  51.589  51.631  51.652  51.650  51.623  ...  39.829
# Angola        48.430  48.450  48.622  48.936  49.343  49.787  ...  45.656
# Albania       38.723  37.695  36.599  35.496  34.435  33.458  ...  12.001
# ...

# %%
del df2["Indicator Name"]
df2.head()
# Out:
#                 1960    1961    1962    1963    1964    1965    1966    1967  \
# Country Name
# Aruba         35.679  34.529  33.320  32.050  30.737  29.413  28.121  26.908
# Afghanistan   51.279  51.373  51.457  51.530  51.589  51.631  51.652  51.650
# Angola        49.080  48.779  48.547  48.430  48.450  48.622  48.936  49.343
# Albania       40.924  40.368  39.627  38.723  37.695  36.599  35.496  34.435
# Andorra          NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#                 1968    1969  ...    2010    2011    2012    2013    2014  \
# Country Name                  ...
# Aruba         25.817  24.872  ...  11.214  11.123  11.090  11.111  11.179
# Afghanistan   51.623  51.574  ...  39.829  38.750  37.690  36.670  35.706
# Angola        49.787  50.231  ...  45.656  45.102  44.493  43.847  43.182
# Albania       33.458  32.590  ...  12.001  12.100  12.197  12.257  12.259
# Andorra          NaN     NaN  ...   9.800     NaN   9.500     NaN     NaN
#
# ...

# %%
years = list(map(str, range(1960,2017)))

# %%
df2.head()
# Out:
#                 1960    1961    1962    1963    1964    1965    1966    1967  \
# Country Name
# Aruba         35.679  34.529  33.320  32.050  30.737  29.413  28.121  26.908
# Afghanistan   51.279  51.373  51.457  51.530  51.589  51.631  51.652  51.650
# Angola        49.080  48.779  48.547  48.430  48.450  48.622  48.936  49.343
# Albania       40.924  40.368  39.627  38.723  37.695  36.599  35.496  34.435
# Andorra          NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#                 1968    1969  ...    2010    2011    2012    2013    2014  \
# Country Name                  ...
# Aruba         25.817  24.872  ...  11.214  11.123  11.090  11.111  11.179
# Afghanistan   51.623  51.574  ...  39.829  38.750  37.690  36.670  35.706
# Angola        49.787  50.231  ...  45.656  45.102  44.493  43.847  43.182
# Albania       33.458  32.590  ...  12.001  12.100  12.197  12.257  12.259
# Andorra          NaN     NaN  ...   9.800     NaN   9.500     NaN     NaN
#
# ...

# %%
df2.isna()
# Out:
#                1960   1961   1962   1963   1964   1965   1966   1967   1968  \
# Country Name
# Aruba         False  False  False  False  False  False  False  False  False
# Afghanistan   False  False  False  False  False  False  False  False  False
# Angola        False  False  False  False  False  False  False  False  False
# Albania       False  False  False  False  False  False  False  False  False
# Andorra        True   True   True   True   True   True   True   True   True
# ...             ...    ...    ...    ...    ...    ...    ...    ...    ...
# Kosovo         True   True   True   True   True   True   True   True   True
# Yemen, Rep.   False  False  False  False  False  False  False  False  False
# South Africa  False  False  False  False  False  False  False  False  False
# Zambia        False  False  False  False  False  False  False  False  False
# Zimbabwe      False  False  False  False  False  False  False  False  False
#
# ...

# %%
df_nonan = df2.fillna(0)

# %%
df_nonan["Mean"] = df_nonan.mean(axis = 1)
#del df_nonan["Total"]

# %%
df_nonan.head(10)
# Out:
#                            1960       1961       1962       1963       1964  \
# Country Name
# Aruba                 35.679000  34.529000  33.320000  32.050000  30.737000
# Afghanistan           51.279000  51.373000  51.457000  51.530000  51.589000
# Angola                49.080000  48.779000  48.547000  48.430000  48.450000
# Albania               40.924000  40.368000  39.627000  38.723000  37.695000
# Andorra                0.000000   0.000000   0.000000   0.000000   0.000000
# Arab World            47.790076  47.558391  47.327603  47.091616  46.844209
# United Arab Emirates  47.266000  46.705000  46.093000  45.426000  44.694000
# Argentina             23.775000  23.569000  23.372000  23.191000  23.033000
# Armenia               38.509000  37.217000  35.561000  33.629000  31.540000
# American Samoa         0.000000   0.000000   0.000000   0.000000   0.000000
#
#                            1965       1966      1967       1968       1969  \
# Country Name
# ...

# %%
df_nonan_mean = df_nonan.sort_values(["Mean"], ascending = False, axis = 0)
#df_nonan["Mean"].plot(kind="hist")

# %%
df_nonan_mean_top5 = df_nonan_mean.head()

# %%
dfx = df_nonan_mean_top5[years].transpose()

# %%
dfx.plot(kind="area", stacked = False)

# %%
dfx.plot(kind="hist", stacked = True)

# %%
df_nonan_mean_top5.head(10)
# Out:
#                 1960    1961    1962    1963    1964    1965    1966    1967  \
# Country Name
# Niger         58.122  58.194  58.227  58.214  58.152  58.037  57.871  57.663
# Mali          50.189  50.132  50.103  50.099  50.113  50.143  50.184  50.233
# Angola        49.080  48.779  48.547  48.430  48.450  48.622  48.936  49.343
# Chad          45.764  45.669  45.588  45.532  45.512  45.550  45.667  45.870
# Uganda        49.055  48.939  48.845  48.769  48.710  48.661  48.616  48.572
#
#                 1968    1969  ...    2011    2012    2013    2014    2015  \
# Country Name                  ...
# Niger         57.431  57.187  ...  49.374  48.929  48.466  47.988  47.502
# Mali          50.282  50.326  ...  45.769  45.129  44.482  43.843  43.226
# Angola        49.787  50.231  ...  45.102  44.493  43.847  43.182  42.520
# Chad          46.154  46.509  ...  46.010  45.420  44.841  44.276  43.730
# Uganda        48.529  48.487  ...  44.007  43.248  42.428  41.564  40.680
#
# ...

# %%
#df_nonan_mean_transposed = df_nonan_mean[years].transpose()

# %%
df_nonan_mean_transposed.head()
# Out:
# Country Name   Niger    Mali  Angola    Chad  Uganda  Afghanistan  \
# 1960          58.122  50.189  49.080  45.764  49.055       51.279
# 1961          58.194  50.132  48.779  45.669  48.939       51.373
# 1962          58.227  50.103  48.547  45.588  48.845       51.457
# 1963          58.214  50.099  48.430  45.532  48.769       51.530
# 1964          58.152  50.113  48.450  45.512  48.710       51.589
#
# Country Name  Yemen, Rep.  Malawi  Burundi  Somalia  ...  San Marino  \
# 1960               53.504  51.405   48.510   47.630  ...         0.0
# 1961               53.786  51.575   48.446   47.520  ...         0.0
# 1962               54.089  51.736   48.391   47.424  ...         0.0
# 1963               54.413  51.884   48.338   47.339  ...         0.0
# 1964               54.750  52.016   48.283   47.261  ...         0.0
#
# Country Name  American Samoa  Monaco  Tuvalu  British Virgin Islands  \
# 1960                     0.0     0.0     0.0                     0.0
# ...

# %%
df_nonan_mean.head().plot(kind="area")

# %%
df3 = df2[years].transpose()
df3.head()
# Out:
# Country Name   Aruba  Afghanistan  Angola  Albania  Andorra  Arab World  \
# 1960          35.679       51.279  49.080   40.924      NaN   47.790076
# 1961          34.529       51.373  48.779   40.368      NaN   47.558391
# 1962          33.320       51.457  48.547   39.627      NaN   47.327603
# 1963          32.050       51.530  48.430   38.723      NaN   47.091616
# 1964          30.737       51.589  48.450   37.695      NaN   46.844209
#
# Country Name  United Arab Emirates  Argentina  Armenia  American Samoa  ...  \
# 1960                        47.266     23.775   38.509             NaN  ...
# 1961                        46.705     23.569   37.217             NaN  ...
# 1962                        46.093     23.372   35.561             NaN  ...
# 1963                        45.426     23.191   33.629             NaN  ...
# 1964                        44.694     23.033   31.540             NaN  ...
#
# Country Name  Virgin Islands (U.S.)  Vietnam  Vanuatu      World   Samoa  \
# ...

# %%
df3.index = df3.index.map(int)
df4 = df3.head()
df4.plot(kind = "area",
        stacked = False,
        figsize=(20,10))

# %%
df["1960"].plot(kind = "hist")
plt.xlabel(df["Country Name"].all)
# Out:
# Text(0.5, 0, '<bound method Series.all of 0             Aruba\n1       Afghanistan\n2            Angola\n3           Albania\n4           Andorra\n           ...     \n259          Kosovo\n260     Yemen, Rep.\n261    South Africa\n262          Zambia\n263        Zimbabwe\nName: Country Name, Length: 264, dtype: object>')
